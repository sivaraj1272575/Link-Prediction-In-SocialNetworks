# %%
#Mounting google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Installing networkx Library
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (2.5.1)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx) (4.4.2)

# %%
#Importing Required Libraries
import networkx #For handling Network graphs
import random
import csv
import numpy as np
import pandas as pd
from tensorflow.keras.layers import Dense,Input,Activation,BatchNormalization
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import Normalizer
from tensorflow.keras.losses import categorical_crossentropy
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam
from keras.utils import np_utils

# %%
#stroing dataset path
path='/content/drive/MyDrive/SENA/facebookdata.txt'

# %%
#Loading dataset into dataset as graph in variable
with open(path,'rb') as file:
  graph=networkx.read_edgelist(file)
networkx.draw_spectral(graph,with_labels = True)

# %%
def Generate_False_Graph(Graph,neg_no):
  """
  Input : a graph as Networkx class
          number of negative samples
  Output :neg_no number of false edges (edges which does not exist in the graph)  
          and build a new graph using negative edges
  """
  Negative_graph= networkx.Graph() 
  count=0
  while (count<neg_no):

    [source,target]=random.sample(Graph.nodes(),2) # pick random two nodes in the graph

    try :

      short_path=networkx.shortest_path_length(Graph,source,target)
      if(short_path>=2):# there does not exist a direct edges betwwen them
         Negative_graph.add_edge(source,target, positive="False") # adding the false edges in the new graph created
         count += 1
    except:
       pass

  return Negative_graph

# %%
def Extract_Sample(Graph,pos_no,neg_no):
  """
  Input : a graph as Networkx class
  Output : List of Positive and Negative samples
  """

  no_edges=Graph.number_of_edges()

  # Poistive samples

  pos_graph = networkx.Graph()
  positves=random.sample(Graph.edges(),pos_no)
  
  pos_graph.add_edges_from(positves, positive="True")
  networkx.write_edgelist(pos_graph, "positive_graph.txt", data=['positive'])

  # Negative Samples

  neg_graph=Generate_False_Graph(Graph,neg_no)
  networkx.write_edgelist(neg_graph, "negatvie_graph.txt", data=['positive'])

  return pos_graph.edges(),neg_graph.edges()

# %%
def common_neighbors(Graph, edges):
    """
    Input : graph as network class and edges
    Output: Common neigbors of the vertices connected by the given edge
    """
    result = []
    for edge in edges:
        src, dest = edge[0], edge[1]
        src_neighbor, dest_neighbor = set(Graph.neighbors(src)), set(Graph.neighbors(dest))
        count = len(src_neighbor.intersection(dest_neighbor))
        result.append((src, dest, count))
    return result

# %%
def Extract_feature(Graph,positives,negatives):
  """
  Input: Graph as network class
         Positive dataset(Nodes having edges among them)
         Negative Dataset(Nodes having shortest path greater than 2)
  Output:Features of the two nodes in the given dataset
         Features: Common Neighbours, Jacaard Coefficient, Resource allocation index, Adamic Adar Coefficient, Preferential Attachment
  """
  data = []
  feature_name = [common_neighbors,networkx.resource_allocation_index,networkx.jaccard_coefficient, networkx.adamic_adar_index, networkx.preferential_attachment]
  label = ["label"] + ["1" for i in range(len(positives))] + ["0" for i in range(len(negatives))]
  for func in feature_name:
    preds = func(Graph, positives)
    feature = [func.__name__] + [i[2] for i in preds]
    preds = func(Graph, negatives)
    feature = feature + [i[2] for i in preds]
    data.append(feature)
  data.append(label)
  col_names = []
  records = []
  for col in data:
    col_names.append(col[0])
    records.append(col[1:])
  records = np.array((records)).T
  csvfile = pd.DataFrame(records, columns = col_names).to_csv('features.csv')

# %%
#Extracting 5000 samples for each dataset
x,y=Extract_Sample(graph,10000,10000)

# %%
Extract_feature(graph, x, y)

# %%
dataset=pd.read_csv("features.csv")
x=dataset.iloc[:,1:-1].values
y=dataset.iloc[:,-1].values

# %%
def rand_hexcolor():
   """
   Input :None
   Output : Random color code in hexadecimal format
   Process:pick random number and convert ot hexadecimal
   """
  
   rgb = ""

   for _ in "RGB": # creating color for each channel
       i = random.randrange(0, 2**8)
       rgb += i.to_bytes(1, "big").hex()
   return '#'+rgb

# %%
numbercol
# Out:
# {0: '#17d7d0', 1: '#61752f'}

# %%
k=[0,1]
numbers=set(k.copy())
numbercol={i:rand_hexcolor() for i in numbers } # giving each number a color
    
from sklearn.manifold import TSNE # tsne converts the image to  dimensional feature vector which is used for plotting

# dimensionality reduction for viewing 400 dimesion hyperspace in 2d space    
tsne = TSNE(metric='cosine') # we use cosine metric which finds similarty between two feature vectors(pixels of the image)
embed_tsne = tsne.fit_transform(np.array((x))) # converting  400 feature
plt.figure(figsize=(35, 35)) # assigning size for each scatter plot

for idx in range(len(x)):# iterating through all training data
    plt.scatter(*embed_tsne[idx, :],c=numbercol[y[idx]]) # each point is marked in the  plot with tnse feature considering as coordinate with color chosen for that label corresponding to the record

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
y_train = np_utils.to_categorical(y_train).astype('float32')
y_test = np_utils.to_categorical(y_test).astype('float32')

# %%
y_train.shape
# Out:
# (13396, 2)

# %%
#Building the base model
model = Sequential()
model.add(Input(len(x[0])))
model.add(BatchNormalization(axis=-1))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dense(2, activation='softmax'))

# %%
#Compiling the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#Model training
model.fit(X_train, y_train, batch_size=200, epochs=1000)
# Out:
# Epoch 1/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9783
# Epoch 2/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 0.9787
# Epoch 3/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9788
# Epoch 4/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9785
# Epoch 5/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9795
# Epoch 6/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9784
# Epoch 7/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0672 - accuracy: 0.9780
# Epoch 8/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9792
# Epoch 9/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9782
# Epoch 10/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9787
# Epoch 11/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0666 - accuracy: 0.9786
# Epoch 12/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0666 - accuracy: 0.9777
# Epoch 13/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 0.9790
# Epoch 14/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0671 - accuracy: 0.9787
# Epoch 15/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0671 - accuracy: 0.9785
# Epoch 16/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0674 - accuracy: 0.9778
# Epoch 17/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9781
# Epoch 18/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9786
# Epoch 19/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0672 - accuracy: 0.9786
# Epoch 20/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0669 - accuracy: 0.9782
# Epoch 21/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 0.9784
# Epoch 22/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 0.9782
# Epoch 23/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 0.9784
# Epoch 24/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9781
# Epoch 25/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0676 - accuracy: 0.9783
# Epoch 26/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9792
# Epoch 27/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9791
# Epoch 28/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0669 - accuracy: 0.9787
# Epoch 29/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9789
# Epoch 30/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9789
# Epoch 31/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 0.9794
# Epoch 32/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9787
# Epoch 33/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0666 - accuracy: 0.9787
# Epoch 34/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 0.9788
# Epoch 35/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0666 - accuracy: 0.9787
# Epoch 36/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0666 - accuracy: 0.9788
# Epoch 37/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 0.9788
# Epoch 38/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0672 - accuracy: 0.9780
# Epoch 39/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9788
# Epoch 40/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9778
# Epoch 41/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9787
# Epoch 42/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9779
# Epoch 43/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0668 - accuracy: 0.9792
# Epoch 44/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0671 - accuracy: 0.9783
# Epoch 45/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9784
# Epoch 46/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9785
# Epoch 47/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9790
# Epoch 48/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0672 - accuracy: 0.9787
# Epoch 49/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0668 - accuracy: 0.9782
# Epoch 50/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9783
# Epoch 51/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9788
# Epoch 52/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9786
# Epoch 53/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9787
# Epoch 54/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9784
# Epoch 55/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9790
# Epoch 56/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9781
# Epoch 57/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9783
# Epoch 58/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9784
# Epoch 59/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 0.9784
# Epoch 60/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9787
# Epoch 61/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9782
# Epoch 62/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9778
# Epoch 63/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9781
# Epoch 64/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9787
# Epoch 65/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9781
# Epoch 66/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9788
# Epoch 67/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9786
# Epoch 68/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9783
# Epoch 69/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9788
# Epoch 70/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 0.9780
# Epoch 71/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9789
# Epoch 72/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9793
# Epoch 73/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9787
# Epoch 74/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0672 - accuracy: 0.9782
# Epoch 75/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9784
# Epoch 76/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0671 - accuracy: 0.9785
# Epoch 77/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9789
# Epoch 78/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9780
# Epoch 79/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0675 - accuracy: 0.9781
# Epoch 80/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9787
# Epoch 81/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 0.9791
# Epoch 82/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9784
# Epoch 83/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9782
# Epoch 84/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9785
# Epoch 85/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0676 - accuracy: 0.9778
# Epoch 86/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9780
# Epoch 87/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9785
# Epoch 88/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9789
# Epoch 89/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9788
# Epoch 90/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9788
# Epoch 91/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0671 - accuracy: 0.9782
# Epoch 92/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9783
# Epoch 93/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9781
# Epoch 94/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9778
# Epoch 95/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9783
# Epoch 96/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9787
# Epoch 97/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0665 - accuracy: 0.9777
# Epoch 98/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9789
# Epoch 99/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9781
# Epoch 100/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0670 - accuracy: 0.9779
# Epoch 101/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9783
# Epoch 102/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9784
# Epoch 103/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9779
# Epoch 104/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9786
# Epoch 105/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9786
# Epoch 106/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9789
# Epoch 107/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9792
# Epoch 108/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9786
# Epoch 109/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9792
# Epoch 110/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9781
# Epoch 111/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9784
# Epoch 112/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9784
# Epoch 113/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9789
# Epoch 114/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9784
# Epoch 115/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9783
# Epoch 116/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9787
# Epoch 117/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9785
# Epoch 118/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9790
# Epoch 119/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9785
# Epoch 120/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9786
# Epoch 121/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9784
# Epoch 122/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0640 - accuracy: 0.9787
# Epoch 123/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9781
# Epoch 124/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0671 - accuracy: 0.9778
# Epoch 125/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0644 - accuracy: 0.9785
# Epoch 126/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0666 - accuracy: 0.9784
# Epoch 127/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9785
# Epoch 128/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9791
# Epoch 129/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9781
# Epoch 130/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9777
# Epoch 131/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9785
# Epoch 132/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9785
# Epoch 133/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9795
# Epoch 134/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9788
# Epoch 135/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9786
# Epoch 136/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0663 - accuracy: 0.9787
# Epoch 137/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9788
# Epoch 138/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9784
# Epoch 139/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9778
# Epoch 140/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9781
# Epoch 141/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9787
# Epoch 142/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9789
# Epoch 143/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9783
# Epoch 144/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9791
# Epoch 145/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9787
# Epoch 146/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0668 - accuracy: 0.9781
# Epoch 147/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0654 - accuracy: 0.9786
# Epoch 148/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9782
# Epoch 149/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9787
# Epoch 150/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9790
# Epoch 151/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9787
# Epoch 152/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9787
# Epoch 153/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9787
# Epoch 154/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9776
# Epoch 155/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9789
# Epoch 156/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9781
# Epoch 157/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9787
# Epoch 158/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9778
# Epoch 159/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9784
# Epoch 160/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9786
# Epoch 161/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9784
# Epoch 162/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9785
# Epoch 163/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9778
# Epoch 164/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9784
# Epoch 165/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9787
# Epoch 166/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9784
# Epoch 167/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0655 - accuracy: 0.9787
# Epoch 168/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9787
# Epoch 169/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9787
# Epoch 170/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9784
# Epoch 171/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0652 - accuracy: 0.9789
# Epoch 172/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 0.9790
# Epoch 173/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9778
# Epoch 174/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9781
# Epoch 175/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0666 - accuracy: 0.9787
# Epoch 176/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9784
# Epoch 177/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9781
# Epoch 178/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9784
# Epoch 179/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9781
# Epoch 180/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9788
# Epoch 181/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0644 - accuracy: 0.9783
# Epoch 182/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9781
# Epoch 183/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9781
# Epoch 184/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9787
# Epoch 185/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 0.9783
# Epoch 186/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9782
# Epoch 187/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9785
# Epoch 188/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9784
# Epoch 189/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9789
# Epoch 190/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0652 - accuracy: 0.9780
# Epoch 191/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9783
# Epoch 192/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0666 - accuracy: 0.9776
# Epoch 193/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0669 - accuracy: 0.9778
# Epoch 194/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9778
# Epoch 195/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9784
# Epoch 196/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9787
# Epoch 197/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9783
# Epoch 198/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0663 - accuracy: 0.9784
# Epoch 199/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0676 - accuracy: 0.9782
# Epoch 200/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0669 - accuracy: 0.9784
# Epoch 201/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9783
# Epoch 202/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 0.9778
# Epoch 203/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0643 - accuracy: 0.9792
# Epoch 204/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0652 - accuracy: 0.9792
# Epoch 205/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9789
# Epoch 206/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0648 - accuracy: 0.9790
# Epoch 207/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 0.9789
# Epoch 208/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9784
# Epoch 209/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0665 - accuracy: 0.9785
# Epoch 210/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9786
# Epoch 211/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9786
# Epoch 212/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 0.9789
# Epoch 213/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9784
# Epoch 214/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9785
# Epoch 215/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9795
# Epoch 216/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9783
# Epoch 217/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9785
# Epoch 218/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0652 - accuracy: 0.9786
# Epoch 219/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0642 - accuracy: 0.9784
# Epoch 220/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0650 - accuracy: 0.9789
# Epoch 221/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9787
# Epoch 222/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 0.9789
# Epoch 223/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9785
# Epoch 224/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0655 - accuracy: 0.9780
# Epoch 225/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0644 - accuracy: 0.9786
# Epoch 226/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9792
# Epoch 227/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9789
# Epoch 228/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9784
# Epoch 229/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9782
# Epoch 230/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0652 - accuracy: 0.9790
# Epoch 231/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9784
# Epoch 232/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9781
# Epoch 233/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9786
# Epoch 234/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9790
# Epoch 235/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9787
# Epoch 236/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9783
# Epoch 237/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9787
# Epoch 238/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0657 - accuracy: 0.9795
# Epoch 239/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9782
# Epoch 240/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9790
# Epoch 241/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9790
# Epoch 242/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9790
# Epoch 243/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9792
# Epoch 244/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9789
# Epoch 245/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9786
# Epoch 246/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0654 - accuracy: 0.9787
# Epoch 247/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9781
# Epoch 248/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9786
# Epoch 249/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9784
# Epoch 250/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0656 - accuracy: 0.9788
# Epoch 251/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0644 - accuracy: 0.9789
# Epoch 252/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0648 - accuracy: 0.9782
# Epoch 253/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0652 - accuracy: 0.9792
# Epoch 254/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9791
# Epoch 255/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9786
# Epoch 256/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 0.9788
# Epoch 257/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9788
# Epoch 258/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9784
# Epoch 259/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9780
# Epoch 260/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 0.9783
# Epoch 261/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0647 - accuracy: 0.9782
# Epoch 262/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9787
# Epoch 263/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9783
# Epoch 264/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9780
# Epoch 265/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0655 - accuracy: 0.9790
# Epoch 266/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9782
# Epoch 267/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9784
# Epoch 268/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0644 - accuracy: 0.9781
# Epoch 269/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9786
# Epoch 270/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9787
# Epoch 271/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 0.9787
# Epoch 272/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9781
# Epoch 273/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0661 - accuracy: 0.9784
# Epoch 274/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0662 - accuracy: 0.9788
# Epoch 275/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0648 - accuracy: 0.9786
# Epoch 276/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9793
# Epoch 277/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9785
# Epoch 278/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 0.9792
# Epoch 279/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9784
# Epoch 280/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9786
# Epoch 281/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9778
# Epoch 282/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9787
# Epoch 283/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9782
# Epoch 284/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0652 - accuracy: 0.9794
# Epoch 285/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0642 - accuracy: 0.9784
# Epoch 286/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9784
# Epoch 287/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9782
# Epoch 288/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9788
# Epoch 289/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9787
# Epoch 290/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0658 - accuracy: 0.9789
# Epoch 291/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 0.9784
# Epoch 292/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9781
# Epoch 293/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9789
# Epoch 294/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9785
# Epoch 295/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0641 - accuracy: 0.9786
# Epoch 296/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0641 - accuracy: 0.9793
# Epoch 297/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0652 - accuracy: 0.9784
# Epoch 298/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9784
# Epoch 299/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0636 - accuracy: 0.9791
# Epoch 300/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0648 - accuracy: 0.9787
# Epoch 301/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9786
# Epoch 302/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0648 - accuracy: 0.9788
# Epoch 303/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9784
# Epoch 304/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0656 - accuracy: 0.9787
# Epoch 305/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9789
# Epoch 306/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9787
# Epoch 307/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9784
# Epoch 308/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0659 - accuracy: 0.9781
# Epoch 309/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9783
# Epoch 310/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9789
# Epoch 311/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9789
# Epoch 312/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0648 - accuracy: 0.9789
# Epoch 313/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9782
# Epoch 314/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9790
# Epoch 315/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9786
# Epoch 316/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0652 - accuracy: 0.9790
# Epoch 317/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9786
# Epoch 318/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9785
# Epoch 319/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0646 - accuracy: 0.9792
# Epoch 320/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9784
# Epoch 321/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9781
# Epoch 322/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 0.9789
# Epoch 323/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9791
# Epoch 324/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0644 - accuracy: 0.9793
# Epoch 325/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0648 - accuracy: 0.9787
# Epoch 326/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0642 - accuracy: 0.9787
# Epoch 327/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9787
# Epoch 328/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9786
# Epoch 329/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 0.9786
# Epoch 330/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0651 - accuracy: 0.9794
# Epoch 331/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0647 - accuracy: 0.9789
# Epoch 332/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9784
# Epoch 333/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0652 - accuracy: 0.9790
# Epoch 334/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9785
# Epoch 335/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9781
# Epoch 336/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9787
# Epoch 337/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9787
# Epoch 338/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0650 - accuracy: 0.9788
# Epoch 339/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 0.9791
# Epoch 340/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0656 - accuracy: 0.9787
# Epoch 341/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9787
# Epoch 342/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0647 - accuracy: 0.9789
# Epoch 343/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0644 - accuracy: 0.9788
# Epoch 344/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9795
# Epoch 345/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9788
# Epoch 346/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9784
# Epoch 347/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0640 - accuracy: 0.9794
# Epoch 348/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0646 - accuracy: 0.9785
# Epoch 349/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0662 - accuracy: 0.9790
# Epoch 350/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0652 - accuracy: 0.9792
# Epoch 351/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0638 - accuracy: 0.9789
# Epoch 352/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0638 - accuracy: 0.9788
# Epoch 353/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9788
# Epoch 354/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0659 - accuracy: 0.9784
# Epoch 355/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0659 - accuracy: 0.9777
# Epoch 356/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9785
# Epoch 357/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0673 - accuracy: 0.9779
# Epoch 358/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9778
# Epoch 359/1000
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0665 - accuracy: 0.9785
# Epoch 360/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9788
# Epoch 361/1000
# 67/67 [==============================] - 0s 3ms/step - loss: 0.0644 - accuracy: 0.9794
# Epoch 362/1000
# 31/67 [============>.................] - ETA: 0s - loss: 0.0653 - accuracy: 0.9781
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-e0677f4b7262> in <module>()
#       1 #Model training
# ----> 2 model.fit(X_train, y_train, batch_size=200, epochs=1000)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model.evaluate(X_test,y_test)
# Out:
# 207/207 [==============================] - 0s 2ms/step - loss: 0.0728 - accuracy: 0.9758
# [0.07280298322439194, 0.975753903388977]

# %%
model.save_weights('/content/drive/MyDrive/SENA/model.h5')

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('/content/drive/MyDrive/SENA/model.h5')

# %%
model.input
# Out:
# <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'input_5')>

# %%
X = X_test[3000]
X = np.expand_dims(X, axis=0)

# %%
np.argmax(model.predict(X))
# Out:
# 0

# %%
y_test[3000]
# Out:
# array([1., 0.], dtype=float32)
